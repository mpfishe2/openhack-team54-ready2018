# %%
import os
from os import listdir
from os.path import isfile, join
import cv2
import numpy as np
import os
from PIL import Image, ImageOps
# Import the matplotlib libraries
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import matplotlib.image as im
import numpy as np
from PIL import Image

# %%
images_path = 'gear_images/'

# %%
def pad_and_resize(im_pth, desired_size):
    print(im_pth)
    im = cv2.imread(im_pth)
    old_size = im.shape[:2] # old_size is in (height, width) format

    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])

    # new_size should be in (width, height) format

    im = cv2.resize(im, (new_size[1], new_size[0]))

    delta_w = desired_size - new_size[1]
    delta_h = desired_size - new_size[0]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)

    color = [255, 255, 255]
    new_im = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT,
        value=color) 
    cv2.imwrite(im_pth, new_im)
    
    print(new_im.shape)
    
def print_size(im_pth):
    im = cv2.imread(im_pth)
    old_size = im.shape[:2] # old_size is in (height, width) format
    print(old_size)

# %%
subdirectories = [x[0] for x in os.walk(images_path) \
               if '.ipynb_checkpoints' not in x[0] and x[0] != 'gear_images/']


for sub in subdirectories:
    files = [sub + '/' + f for f in listdir(sub) if isfile(join(sub, f))]
    for f in files:
        pad_and_resize(f, 128)
        print_size(f)
# Out:
# gear_images/boots/51fxSrdRH3L._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10211759x1104651_zm.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/51hAX8xT6bL._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/896260.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10018755x1036824_zm.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10305295x1039826_zm.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/51QgEWGyZ-L._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/51YZs+KEHML._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/51yQeovtEdL._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10305296x1039826_zm.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/515b5yc46SL._AC_US436_QL65_.jpg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10270695x1051081_zm.jpeg
# (128, 128, 3)
# (128, 128)
# gear_images/boots/10345908x1010938_zm.jpeg
# (128, 128, 3)
# (128, 128)
# ...

# %%
distro = {}
for f in files:
    np_array = np.array(Image.open(f))
    for d1 in np_array:
        for d2 in d1:
            for element in d2:
                if element in distro:
                    distro[element] += 1
                else:
                    distro[element] = 1

print(distro)
distro_list = []
for item in distro:
    distro_list.append([item, distro[item]])
# Out:
# {0: 648, 1: 124, 2: 148, 3: 192, 4: 206, 5: 211, 6: 237, 7: 252, 8: 283, 9: 273, 10: 312, 11: 350, 12: 327, 13: 392, 14: 390, 15: 430, 16: 447, 17: 478, 18: 529, 19: 551, 20: 615, 21: 652, 22: 645, 23: 720, 24: 825, 25: 798, 26: 940, 27: 894, 28: 993, 29: 995, 30: 1031, 31: 1053, 32: 1156, 33: 1174, 34: 1235, 35: 1267, 36: 1268, 37: 1284, 38: 1334, 39: 1302, 40: 1367, 41: 1471, 42: 1490, 43: 1464, 44: 1669, 45: 1619, 46: 1704, 47: 1685, 48: 1852, 49: 1866, 50: 1897, 51: 1898, 52: 1929, 53: 1962, 54: 1874, 55: 1937, 56: 1896, 57: 1858, 58: 1828, 59: 1811, 60: 1815, 61: 1737, 62: 1738, 63: 1657, 64: 1566, 65: 1635, 66: 1514, 67: 1551, 68: 1433, 69: 1513, 70: 1510, 71: 1474, 72: 1459, 73: 1382, 74: 1347, 75: 1440, 76: 1384, 77: 1360, 78: 1284, 79: 1371, 80: 1359, 81: 1351, 82: 1291, 83: 1323, 84: 1404, 85: 1282, 86: 1352, 87: 1338, 88: 1375, 89: 1353, 90: 1312, 91: 1379, 92: 1415, 93: 1442, 94: 1408, 95: 1471, 96: 1489, 97: 1485, 98: 1571, 99: 1581, 100: 1417, 101: 1450, 102: 1435, 103:
# ...

# %%
plt.hist(distro, bins=distro.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4126675fb153> in <module>()
# ----> 1 plt.hist(distro, bins=distro.keys())
#
# /anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# /anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
# Ensure for each image that the pixel range is from 0 to 255 (inclusive or [0, 255]) which is also called “contrast stretching”.
filepath = "/gearimages/gear_images/"
img_real = Image.open(filepath+'/hardshell_jackets/10116634x1038116_zm.jpeg')

# %%
# Save the data to disk in a format the team deems appropriate for easily reading back in (see Hints).

# %%
ImageOps.equalize(img_real)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F1E90DC32E8>

# %%
imshow(img_real)

# %%
gg = filepath+'hardshell_jackets/10116634x1038116_zm.jpeg'

# %%
gg
# Out:
# '/gearimages/gear_images/hardshell_jackets/10116634x1038116_zm.jpeg'

# %%
subdirectories[0]
# Out:
# 'gear_images/boots'

# %%
import numpy as np
from PIL import Image

def normalize(arr):
    """
    Linear normalization
    http://en.wikipedia.org/wiki/Normalization_%28image_processing%29
    """
    arr = arr.astype('float')
    # Do not touch the alpha channel
    for i in range(3):
        minval = arr[...,i].min()
        maxval = arr[...,i].max()
        if minval != maxval:
            arr[...,i] -= minval
            arr[...,i] *= (255.0/(maxval-minval))
    return arr

def demo_normalize(FILENAME):
    subdir = FILENAME.split("/")[-2]
    fileName = FILENAME.split("/")[-1]
    img = Image.open(FILENAME).convert('RGB')
    arr = np.array(img)
    new_img = Image.fromarray(normalize(arr).astype('uint8'),'RGB')
    if not os.path.exists('normalized_imgs/{0}'.format(subdir)):
        os.makedirs('normalized_imgs/{0}'.format(subdir))
    new_img.save('normalized_imgs/{0}/{1}'.format(subdir, fileName))

# %%
demo_normalize('gear_images/hardshell_jackets/10116634x1038116_zm.jpeg')

# %%
img_real = Image.open(filepath+'/hardshell_jackets/10116634x1038116_zm.jpeg')
img_real2 = Image.open("normalized_imgs"+'/hardshell_jackets/10116634x1038116_zm.jpeg')

# %%
filepath+'/hardshell_jackets/10116634x1038116_zm.jpeg'
# Out:
# '/gearimages/gear_images//hardshell_jackets/10116634x1038116_zm.jpeg'

# %%
imshow(img_real)
imshow(img_real2)

# %%
f, axarr = plt.subplots(1,2)
axarr[0].imshow(img_real)
axarr[1].imshow(img_real2)

# %%
my_arr = np.array(img_real2)

# %%
final = []
for arr in my_arr:
    for piece in arr:
        for item in piece:
            final.append(item)

# %%
plt.hist(final)
# Out:
# (array([ 3028.,  7394.,  1933.,  1732.,  1601.,  1533.,  1673.,   684.,
#           374., 29200.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
